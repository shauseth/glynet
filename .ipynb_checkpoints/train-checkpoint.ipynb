# %%
# train.ipynb

# %%
from glynet import *

# %%
data = get_data(transformation = np.cbrt, cutoff = 1.0)
data.head()
# Out:
#             IUPAC       AAA       AAL        ABA        ACL        AIA  \
# 0      Gal(a1-Sp8  4.372858  4.167230  11.961571   2.139711  21.991218
# 1      Glc(a1-Sp8  5.920529  3.816098  12.437614   2.167011   1.000000
# 2      Man(a1-Sp8  4.391430  2.661648   9.542767   2.169314   1.000000
# 3   GalNAc(a1-Sp8  4.667372  2.100263   5.055442  13.607672  31.486598
# 4  GalNAc(a1-Sp15  3.762482  3.430544   3.388678   2.124570  19.338650
#
#         AMA       AOL        BPL       CAA  ...       SNA       STA       TJA  \
# 0  4.239280  4.283983   2.239729  3.885891  ...  4.997460  4.207602  3.703668
# 1  3.767102  4.050202   2.292355  3.085994  ...  6.461637  3.116482  5.832524
# 2  4.571336  4.120613   3.204097  2.252729  ...  6.279191  3.448673  4.214564
# 3  1.858734  2.866164  23.956914  1.820443  ...  3.597608  2.372793  3.050818
# 4  3.519719  3.630171   8.424235  3.442724  ...  1.000000  2.141957  3.097587
#
#          TL       UDA  UEA       VGA        VVL        WFL        WGA
# 0  1.000000  2.142846  1.0  4.903597   4.222035   2.376969   7.461575
# 1  1.000000  2.746133  1.0  5.367763   3.315473   1.980999   7.520612
# 2  2.550254  2.670529  1.0  3.471939   3.379915   2.692877   6.133126
# 3  1.150529  1.741230  1.0  3.958229  33.314936  30.684647  24.644268
# 4  1.433175  2.742227  1.0  4.691258  30.653437  26.789213   5.192208
#
# [5 rows x 51 columns]

# %%
epochs = 250
lr = 0.01
batch_size = 16

# %%
proteins = list(data.columns[1:])
traindata = list(zip(data['IUPAC'], data[proteins].values.tolist()))
glycans, actual, predicted = [], [], []
for i, (held_out, kept_in) in enumerate(ten_fold(traindata)):
    train_losses, test_losses, r2s = [], [], []
    trainloader = prepare_data(kept_in, mode = 'train')
    print('fold', i + 1, 'held out')
    net = GlyNet(n_hidden = 400)
    criterion = nn.MSELoss()
    optimizer = optim.SGD(net.parameters(), lr = lr)
    for epoch in range(epochs):
        train_loss = 0.0
        for inputs, values in trainloader:
            optimizer.zero_grad()
            outputs = net(inputs)
            loss = criterion(values, outputs)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()
        test_inputs, test_values = prepare_data(held_out, mode = 'test')
        with torch.no_grad():
            test_outputs = net(test_inputs)
            test_loss = criterion(test_values, test_outputs).item()
            r2 = r2_score(test_values, test_outputs)
        train_losses.append(train_loss / (600 / batch_size))
        test_losses.append(test_loss)
        r2s.append(r2)
    actual += [actual for glycans, actual in held_out]
    predicted += test_outputs.squeeze(1).tolist()
    glycans += [glycans for glycans, actual in held_out]
    print('train_loss:', round(train_loss / (600 / batch_size), 4))
    print('test_loss:', round(test_loss, 4))
    print('r-squared:', round(r2, 4))
    plot_performance(train_losses, test_losses, r2s)
print('finished training.', '\n')
return actual, predicted, glycans

# %%
path = './results/'
experiment = 'glynet50_lr' + str(lr) + '_epochs' + str(epochs) +'_bs' + str(batch_size)
results = make_results(data, actual, predicted, glycans, experiment, path, proteins, save = True)
plot_all(results, experiment, proteins, filename = path + experiment + '.pdf')

# %%
for protein in proteins:
    results = results.sort_values(protein + ' actual')
    plot_results(results[protein + ' actual'].values, results[protein + ' predicted'].values,
                 title = protein + '_' + experiment, color = color_dict[protein])
